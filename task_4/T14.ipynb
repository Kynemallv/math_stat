# %%
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np

# %%
quantile = float(st.norm.ppf(0.95))
print(f"{quantile = }")
# Out:
# quantile = 1.6448536269514722

# %%
x = np.linspace(0, 5, 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, norm.sf(1.645 - x / np.sqrt(7 / 6)))
